# %% [markdown]
# Q1. Explain why we have to use the Exception class while creating a Custom Exception.

# %% [raw]
# When creating a custom exception in Python, it is essential to use the Exception class (or one of its subclasses) as the base class for
# several reasons-
#
# 1. Inheritance and Integration with Python’s Error Handling System-
#
# Standard Interface:
# By inheriting from the Exception class, our custom exception becomes part of Python's standard exception hierarchy.
# This ensures that it integrates seamlessly with Python's built-in error handling mechanisms.
#
# Catch-All Compatibility:
# Python's try and except blocks are designed to handle exceptions that derive from the Exception class.
# By inheriting from Exception, our custom exception can be caught using standard exception handling techniques.
#
# 2. Consistent Behavior
#
# Built-In Methods:
# The Exception class provides built-in methods and properties that our custom exception inherits. This includes the __init__ method for initializing exception instances and the __str__ method for generating string representations of exceptions.
#
# Error Message Handling:
# Custom exceptions inherit the ability to handle and propagate error messages, which allows you to create meaningful error descriptions.

# %% [markdown]
# Q2. Write a python program to print Python Exception Hierarchy.

# %% [raw]
# To print the Python exception hierarchy, we can use the inspect module to inspect the exception classes and their relationships.

# %%
import inspect
import builtins

def print_exception_hierarchy(base_class, indent=0):
    # Print the class name with indentation
    print(" " * indent + base_class.__name__)
    
    # Iterate over the subclasses of the base class
    for subclass in base_class.__subclasses__():
        print_exception_hierarchy(subclass, indent + 4)

def main():
    # Print the hierarchy starting from the base Exception class
    print("Python Exception Hierarchy:")
    print_exception_hierarchy(Exception)

if __name__ == "__main__":
    main()
# Out:
# Python Exception Hierarchy:
# Exception
#     ArithmeticError
#         FloatingPointError
#         OverflowError
#         ZeroDivisionError
#             DivisionByZero
#             DivisionUndefined
#         DecimalException
#             Clamped
#             Rounded
#                 Underflow
#                 Overflow
#             Inexact
#                 Underflow
#                 Overflow
#             Subnormal
#                 Underflow
#             DivisionByZero
#             FloatOperation
#             InvalidOperation
#                 ConversionSyntax
#                 DivisionImpossible
#                 DivisionUndefined
#                 InvalidContext
#     AssertionError
#     AttributeError
#         FrozenInstanceError
#     BufferError
#     EOFError
#         IncompleteReadError
#     ImportError
#         ModuleNotFoundError
#             PackageNotFoundError
#         ZipImportError
#     LookupError
#         IndexError
#         KeyError
# ...

# %% [markdown]
# Q3. What errors are defined in the ArithmeticError class? Explain any two with an example.

# %% [raw]
# The ArithmeticError class in Python is a base class for errors that occur during arithmetic operations. It is a subclass of the Exception
# class.

# %% [raw]
# Errors Defined in the ArithmeticError Class-
#
# 1.ZeroDivisionError- Raised when a division by zero is attempted.
# 2.OverflowError- Raised when an arithmetic operation exceeds the limits of the data type.
# 3.FloatingPointError- Raised when a floating-point operation fails.
# 4.DecimalError-Raised by operations on the decimal.Decimal class when an arithmetic error occurs (part of the decimal module).

# %%
try:
    result = 10 / 0
except ZeroDivisionError as e:
    print(f"Error: {e}")
# Out:
# Error: division by zero

# %%
import math

try:
    result = math.exp(1000)  # Trying to compute e^1000
except OverflowError as e:
    print(f"Error: {e}")
# Out:
# Error: math range error

# %% [markdown]
# Q4. Why LookupError class is used? Explain with an example KeyError and IndexError.

# %% [raw]
# The LookupError class in Python is a base class for errors that occur when a key or index is not found. It is a subclass
# of the Exception class.
#
# Why LookupError is Used:
#
# Base Class for Lookup Error-
# LookupError acts as a common base class for exceptions that occur when a lookup operation
# (such as accessing an item from a collection) fails.
#
# Organization and Clarity:
# It helps to organize and categorize exceptions related to lookups, making it easier to handle specific lookup errors in a unified way.
#
# 1.Subclasses of LookupError-
#
# KeyError: Raised when a dictionary key is not found.
# IndexError: Raised when a sequence index is out of range.

# %%
#1. KeyError
my_dict = {'name': 'Alice', 'age': 30}

try:
    value = my_dict['address']  # Key 'address' does not exist in the dictionary
except KeyError as e:
    print(f"KeyError: {e}")
# Out:
# KeyError: 'address'

# %%
#2. IndexError
my_list = [1, 2, 3]

try:
    value = my_list[5]  # Index 5 is out of range for the list
except IndexError as e:
    print(f"IndexError: {e}")
# Out:
# IndexError: list index out of range

# %% [markdown]
# Q5. Explain ImportError. What is ModuleNotFoundError?

# %% [raw]
# ImportError is a built-in exception that is raised when an import statement fails to import a module or object.
# This can occur for several reasons, such as when the module or object is not found, or there are issues with the module itself.

# %% [raw]
# ModuleNotFoundError is a subclass of ImportError introduced in Python 3.6. It is raised specifically when an imported module cannot be found.
# This exception provides a more precise and specific error message compared to the generic ImportError.

# %% [markdown]
# Q6. List down some best practices for exception handling in python.

# %% [raw]
# 1. Handle Specific Exceptions
# 2. Avoid Using Bare except
# 3. Use the finally Clause for Cleanup
# 4.Use else Clause for Code That Should Run if No Exception is Raised
# 5. Re-raise Exceptions if Necessary
# 6. Log Exceptions
# 7. Avoid Overusing Exceptions for Control Flow
